# %% [markdown]
# This Notebook is used to give an app permissions to acess a table and run stuff on it. copy the code into a databricks notebook file to run - it can be any notebook. Any time you create a new table or want to add a table to an apps base, run this. make sure to look at the comments for what to fill in.

# %%
import psycopg2
from databricks.sdk import WorkspaceClient

w = WorkspaceClient()
current_user = w.current_user.me().user_name

#you have to regenerate this token each time
#go to powershell on your computer, type in databricks auth token, and hit enter
#it'll generate a long string like this that you can copy in
auth_token = "eyJraWQiOiI2NDZiZWZkNGY5NjYwMTdiNjk1MjRjOTRlMjcxNzljY2YyZmRlZDU1ZGJiMzQ5N2UwZjEwM2EwMzljZjI2ODU3IiwidHlwIjoiYXQrand0IiwiYWxnIjoiUlMyNTYifQ..uqYIIKYqxjaOdhtxdxoxIyrbkeXGeX6oqZKv5DXmhCtVgDd7c0SdC3hQWS5q-i5-KzsCNIq94xSAgcyBGDp4XaAQPoJWj9rn6-TIuFX-_FF-7uG_OCCLRkaf2w-KXwoQdsUvv3c3yyEGgVgc-q6Ra1S2dI5EPIgwj_YSunLmzC-5GoovEmr0vUV3z88YFpwjacjop8CRNkJVUTHFx3Im_uhcReFZaMRhXzIU0abX1hC7a5q1bBSPOqBtKvtkg34nllG5SgYM9gJFsiuY306hiLB_suUb_ixnipFP32lluPsEPU-DYUNXF3euCw0LoqvweVn-lcmBXvYOvYZ-tnU2Yw"


PGHOST = "ep-bitter-cake-d1ajl0h1.database.us-west-2.cloud.databricks.com" 
PGDATABASE = "databricks_postgres"

#this is where you put in the apps credentials
#click on the app, then go to the authorizationtab, and the service principal is right at the top
CLIENT_ID = "3872b02b-3fab-4b2e-bc7c-620693c71a99"


conn = psycopg2.connect(
    host=PGHOST,
    port=5432,
    dbname=PGDATABASE,
    user=current_user,
    password=auth_token,
    sslmode="require"
)


conn.autocommit = True
cursor = conn.cursor()


try:
    grant_schema_query = f'GRANT USAGE ON SCHEMA "sandbox" TO "{CLIENT_ID}";'

    #this is where you input the table you're giving the app access to
    #you should just be able to cpy/paste the table name
    grant_table_query = f'GRANT SELECT ON TABLE "sandbox"."acquisition_data_v3" TO "{CLIENT_ID}";'
    
    print(f"Executing: {grant_schema_query}")
    cursor.execute(grant_schema_query)
    
    print(f"Executing: {grant_table_query}")
    cursor.execute(grant_table_query)
    
    print("Successfully granted App permissions!")
    
except Exception as e:
    print(f"An error occurred: {e}")
finally:
    cursor.close()
    conn.close()
# Out:
# Executing: GRANT USAGE ON SCHEMA "sandbox" TO "3872b02b-3fab-4b2e-bc7c-620693c71a99";
# Executing: GRANT SELECT ON TABLE "sandbox"."acquisition_data_v3" TO "3872b02b-3fab-4b2e-bc7c-620693c71a99";
# Successfully granted App permissions!
